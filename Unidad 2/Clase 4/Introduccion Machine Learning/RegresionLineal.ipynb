# %%
import pandas as pd

df = pd.read_csv('casam2Precio.csv')

df.head()
# Out:
#    Metros Cuadrados (m²)  Precio Total (USD)
# 0                     45              135000
# 1                     46              138000
# 2                     47              141000
# 3                     48              144000
# 4                     49              147000

# %%
x = df[['Metros Cuadrados (m²)']]
y = df[['Precio Total (USD)']]

print(x.head())
print(y.head())
# Out:
#    Metros Cuadrados (m²)
# 0                     45
# 1                     46
# 2                     47
# 3                     48
# 4                     49
#    Precio Total (USD)
# 0              135000
# 1              138000
# 2              141000
# 3              144000
# 4              147000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
prediccion = model.predict([[63]])

print(f'Precio estimado: {prediccion[0][0]:.2f} USD')
# Out:
# Precio estimado: 189000.00 USD
# c:\Users\juand\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = model.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error: {mae:.2f}')
print(f'Mean Squared Error: {mse:.2f}')
print(f'R^2 Score: {r2:.2f}')
# Out:
# Mean Absolute Error: 0.00
# Mean Squared Error: 0.00
# R^2 Score: 1.00

# %%
import pandas as pd

df = pd.read_csv('House_price.csv')

df.head()
# Out:
#    Avg. Area Income  House Age  Number of Rooms  Number of Bedrooms  \
# 0       79545.45857   5.682861         7.009188                4.09
# 1       79248.64245   6.002900         6.730821                3.09
# 2       61287.06718   5.865890         8.512727                5.13
# 3       63345.24005   7.188236         5.586729                3.26
# 4       59982.19723   5.040555         7.839388                4.23
#
#    Area Population         Price  \
# 0      23086.80050  1.059034e+06
# 1      40173.07217  1.505891e+06
# 2      36882.15940  1.058988e+06
# 3      34310.24283  1.260617e+06
# 4      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4548 entries, 0 to 4547
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Avg. Area Income    4548 non-null   float64
#  1   House Age           4548 non-null   float64
#  2   Number of Rooms     4548 non-null   float64
#  3   Number of Bedrooms  4548 non-null   float64
#  4   Area Population     4548 non-null   float64
#  5   Price               4548 non-null   float64
#  6   Address             4548 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 248.8+ KB

# %%
x = df[[
    'Avg. Area Income',
    'House Age',
    'Number of Rooms',
    'Number of Bedrooms',
    'Area Population'
]]

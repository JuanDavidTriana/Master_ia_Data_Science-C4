# %%
# !pip install pandas

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import pandas as pd

# Cargar el archivo
df = pd.read_csv('personas.csv', sep=';')

#ver las primeras filas
print(df.head())
# Out:
#    Nombre  Edad     Ciudad  Unnamed: 3
# 0    Juan    26     Ibague         NaN
# 1   Pedro    56  Monterrey         NaN
# 2  Camilo    15     Bogota         NaN

# %%
#ver las primeras filas
df.head()
# Out:
#    Nombre  Edad     Ciudad  Unnamed: 3
# 0    Juan    26     Ibague         NaN
# 1   Pedro    56  Monterrey         NaN
# 2  Camilo    15     Bogota         NaN

# %%
#Filtrar personas Mayores de 25 años
mayores = df[df['Edad'] > 25]
print(mayores)
# Out:
#   Nombre  Edad     Ciudad  Unnamed: 3
# 0   Juan    26     Ibague         NaN
# 1  Pedro    56  Monterrey         NaN

# %%
# Calcular la edad promedio
promedio = df['Edad'].mean()
print(f"Edad promedio: {promedio}")
# Out:
# Edad promedio: 32.333333333333336

# %%
df_limpio = df.drop("Unnamed: 3", axis= 1)
df_limpio
# Out:
#    Nombre  Edad     Ciudad
# 0    Juan    26     Ibague
# 1   Pedro    56  Monterrey
# 2  Camilo    15     Bogota
